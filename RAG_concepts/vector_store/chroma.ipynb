# %%
from langchain_chroma import Chroma
from langchain_ollama import OllamaEmbeddings
from langchain_core.documents import Document

# %%
docs = [
    Document(
        page_content="Python is a popular programming language used for web development, data science, and artificial intelligence.",

        metadata={"source": "python.txt", "topic": "programming"},
        ),
    Document(
        page_content="The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.",
        metadata={"source": "sports.txt", "topic": "cricket"},
    ),
    Document(

        page_content="Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.",

        metadata={"source": "ml.txt", "topic": "machine_learning"},

    ),

    Document(

        page_content="The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.",

        metadata={"source": "geography.txt", "topic": "nature"},

    ),

    Document(

        page_content="Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.",

        metadata={"source": "energy.txt", "topic": "renewable_energy"},

    ),

]

# %%
vec_store = Chroma(
    embedding_function= OllamaEmbeddings(model='nomic-embed-text'),
    persist_directory='chroma_db',
    collection_name='sample'
)

# %%
vec_store.add_documents(docs)

res = vec_store.get(include=['embeddings','metadatas','documents'])
print(res)
# Out:
# {'ids': ['e8468c75-5ea4-4624-8e3b-db728877088e', '44115ff0-4f87-4294-8a60-10383308d67c', 'b6d87b44-321a-41b5-aaca-f3e900f44e6a', 'f355ffd3-bb73-4488-9229-a661b6624e7e', '70ca868e-63e0-48ad-9a09-56c84c9502c4'], 'embeddings': array([[-0.00182725,  0.04141546, -0.14675866, ..., -0.05213424,
#         -0.07318358,  0.01438711],
#        [ 0.00735757,  0.0739252 , -0.19310905, ..., -0.0460284 ,
#         -0.04709939,  0.00983565],
#        [-0.00682915,  0.04281028, -0.17339639, ..., -0.00081563,
#         -0.02074972, -0.01806264],
#        [ 0.02338139,  0.04502665, -0.19164981, ..., -0.01838585,
#         -0.0637055 ,  0.01552957],
#        [ 0.03785621,  0.07078156, -0.16430716, ..., -0.04752124,
#         -0.05524541, -0.02705772]], shape=(5, 768)), 'documents': ['Python is a popular programming language used for web development, data science, and artificial intelligence.', 'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.', 'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.', 'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.', 'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.'], 'uris': None, 'included': ['embeddings', 'metadatas', 'documents'], 'data': None, 'metadatas': [{'topic': 'programming', 'source': 'python.txt'}, {'source': 'sports.txt', 'topic': 'cricket'}, {'topic': 'machine_learning', 'source': 'ml.txt'}, {'source': 'geography.txt', 'topic': 'nature'}, {'topic': 'renewable_energy', 'source': 'energy.txt'}]}

# %%
doc = [Document(
    page_content="The person's name is Manas Sharma",
    metadata = {"author":"Manas"}
)]
vec_store.add_documents(doc)

res = vec_store.get(include=['metadatas'])
print(res)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[64], line 5
#       1 doc = [Document(
#       2     page_content="The person's name is Manas Sharma",
#       3     metadata = {"author":"Manas"}
#       4 )]
# ----> 5 vector_store.add_documents(doc)
#       6
#       7 res = vector_store.get(include=['metadatas'])
#       8 print(res)
#
# File ~/Desktop/langchain/venv/lib/python3.14/site-packages/langchain_core/vectorstores/base.py:258, in VectorStore.add_documents(self, documents, **kwargs)
#     256     texts = [doc.page_content for doc in documents]
#     257     metadatas = [doc.metadata for doc in documents]
# --> 258     return self.add_texts(texts, metadatas, **kwargs)
#     259 msg = (
#     260     f"`add_documents` and `add_texts` has not been implemented "
#     261     f"for {self.__class__.__name__} "
#     262 )
#     263 raise NotImplementedError(msg)
#
# File ~/Desktop/langchain/venv/lib/python3.14/site-packages/langchain_chroma/vectorstores.py:651, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     649 ids_with_metadata = [ids[idx] for idx in non_empty_ids]
#     650 try:
# --> 651     self._collection.upsert(
#     652         metadatas=metadatas,  # type: ignore[arg-type]
#     653         embeddings=embeddings_with_metadatas,  # type: ignore[arg-type]
#     654         documents=texts_with_metadatas,
#     655         ids=ids_with_metadata,
#     656     )
#     657 except ValueError as e:
#     658     if "Expected metadata value to be" in str(e):
#
# File ~/Desktop/langchain/venv/lib/python3.14/site-packages/chromadb/api/models/Collection.py:530, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#     511 """Create or update records by ID.
#     512
#     513 Args:
#    (...)    519     uris: URIs for loading images.
#     520 """
#     521 upsert_request = self._validate_and_prepare_upsert_request(
#     522     ids=ids,
#     523     embeddings=embeddings,
#    (...)    527     uris=uris,
#     528 )
# --> 530 self._client._upsert(
#     531     collection_id=self.id,
#     532     ids=upsert_request["ids"],
#     533     embeddings=upsert_request["embeddings"],
#     534     metadatas=upsert_request["metadatas"],
#     535     documents=upsert_request["documents"],
#     536     uris=upsert_request["uris"],
#     537     tenant=self.tenant,
#     538     database=self.database,
#     539 )
#
# File ~/Desktop/langchain/venv/lib/python3.14/site-packages/chromadb/api/rust.py:541, in RustBindingsAPI._upsert(self, collection_id, ids, embeddings, metadatas, documents, uris, tenant, database)
#     529 @override
#     530 def _upsert(
#     531     self,
#    (...)    539     database: str = DEFAULT_DATABASE,
#     540 ) -> bool:
# --> 541     return self.bindings.upsert(
#     542         str(collection_id),
#     543         ids,
#     544         embeddings,
#     545         metadatas,
#     546         documents,
#     547         uris,
#     548         tenant,
#     549         database,
#     550     )
#
# InternalError: Error getting collection: Database error: error returned from database: (code: 14) unable to open database file

# %%
#search documents
vec_store.similarity_search(
    query= "which language is used for machine learning",
    k=3   #how many results we want
)
# Out:
# [Document(id='80158407-d90a-4a9a-a04e-a1b281eb8eb7', metadata={'source': 'python.txt', 'topic': 'programming'}, page_content='Python is a popular programming language used for web development, data science, and artificial intelligence.'),
#  Document(id='6ff45217-faa3-4ed9-afe9-4484770b8a2d', metadata={'topic': 'programming', 'source': 'python.txt'}, page_content='Python is a popular programming language used for web development, data science, and artificial intelligence.'),
#  Document(id='37772e87-c230-40aa-bcbc-9b87b3030c47', metadata={'source': 'python.txt', 'topic': 'programming'}, page_content='Python is a popular programming language used for web development, data science, and artificial intelligence.')]

# %%
#search documents with similarity scores
vec_store.similarity_search_with_score(
    query="i am the person?",
    k=3
)
# Out:
# [(Document(id='110e22c7-405f-4969-9484-210d792960ac', metadata={'author': 'Manas Sharma'}, page_content='I am Manas Sharma'),
#   1.0869139432907104),
#  (Document(id='98ef2447-e0da-4378-99fd-f212d9f41981', metadata={'source': 'energy.txt', 'topic': 'renewable_energy'}, page_content='Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.'),
#   1.099170207977295),
#  (Document(id='93772d66-9412-4a05-b761-8919b59f0d1b', metadata={'source': 'energy.txt', 'topic': 'renewable_energy'}, page_content='Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.'),
#   1.099170207977295)]

# %%
#meta data filtering

vec_store.similarity_search_with_score(
    query='',
    filter= {'author':'Manas'},
    k=2
)
# Out:
# []

# %%
vec_store.get(include=["documents","embeddings","metadatas"])
# Out:
# {'ids': ['80158407-d90a-4a9a-a04e-a1b281eb8eb7',
#   '08d4b84d-f3a7-4e30-852e-630ad9ce03b7',
#   '29b624cd-b456-4e59-a4c5-d2cd46b11ca1',
#   '318499ce-9941-45f8-b25d-87a44286a2b2',
#   'd28956c2-9db1-4267-81da-975d82c6f258',
#   '54680e0d-b3b5-4bfc-8bbb-cab3240927f2',
#   '38317035-1db4-4e33-8cd1-e56d67fcac73',
#   'c0b718a1-a7c8-4886-ba7d-513d6598f8ea',
#   'e1aa3aac-7601-4955-a61a-21c62276197d',
#   '97ceeb82-c325-4935-b7d1-6e5f016ad772',
#   '6ff45217-faa3-4ed9-afe9-4484770b8a2d',
#   'e5bb583a-0472-4d13-b7f5-9fe694088fb6',
#   'd0a3be0d-166d-4830-8668-51d63d7ac195',
#   'e23583ef-6dd3-4ff9-b69f-96bb02afaad7',
#   '98ef2447-e0da-4378-99fd-f212d9f41981',
#   '6226bf99-bec2-4681-bdb2-cc47a0608694',
#   '5ab497d4-4e82-4ea2-a09a-68851e6828e9',
#   'd7aef786-b3c1-4823-9535-272deee9535d',
#   '422ff6d7-5f94-449c-802a-9b3d02a3d74a',
#   '4bc430e6-2f4f-4003-b0cf-2a0bc2bff10f',
#   '37772e87-c230-40aa-bcbc-9b87b3030c47',
#   'f730822e-ba87-49cd-9f20-8f678b0222b0',
#   'df5562ca-be2e-415e-baf4-6db5eb228f03',
#   '062ef0db-1ab5-4fcf-87cc-c86c96cdc668',
#   '93772d66-9412-4a05-b761-8919b59f0d1b',
#   '5416ca5b-1c70-461b-a712-9896ea6a7770',
#   '0973a22d-a139-4d28-90be-03bfef728887',
#   '69f9bed7-3e80-42ce-b37f-da0eeea11d61',
#   'b5dedae2-6b2b-4680-9547-ced4629d3430',
#   '056261e5-2db1-4f99-9fdb-bcb941763e0e',
#   'dc50db02-19d4-4a34-8b80-ba9613b0c685',
#   '110e22c7-405f-4969-9484-210d792960ac',
#   'f1f2fa62-5462-46a2-8373-338f7cb3dd26'],
#  'embeddings': array([[-0.01715239, -0.01714413, -0.12987012, ..., -0.03701324,
#          -0.03970392, -0.0426118 ],
#         [ 0.00735757,  0.0739252 , -0.19310905, ..., -0.0460284 ,
#          -0.04709939,  0.00983565],
#         [-0.00682915,  0.04281028, -0.17339639, ..., -0.00081563,
#          -0.02074972, -0.01806264],
#         ...,
#         [-0.00119635,  0.00826253, -0.16780199, ..., -0.03213845,
#          -0.02195565, -0.02404436],
#         [-0.01715239, -0.01714413, -0.12987012, ..., -0.03701324,
#          -0.03970392, -0.0426118 ],
#         [-0.00119635,  0.00826253, -0.16780199, ..., -0.03213845,
#          -0.02195565, -0.02404436]], shape=(33, 768)),
#  'documents': ['I am Manas Sharma',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   "The person's name is Manas Sharma",
#   'I am Manas Sharma',
#   "The person's name is Manas Sharma"],
#  'uris': None,
#  'included': ['documents', 'embeddings', 'metadatas'],
#  'data': None,
#  'metadatas': [{'source': 'python.txt',
#    'topic': 'programming',
#    'author': 'Manas Sharma'},
#   {'source': 'sports.txt', 'topic': 'cricket'},
#   {'source': 'ml.txt', 'topic': 'machine_learning'},
#   {'source': 'geography.txt', 'topic': 'nature'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'source': 'python.txt', 'topic': 'programming'},
#   {'source': 'sports.txt', 'topic': 'cricket'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'source': 'geography.txt', 'topic': 'nature'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'source': 'python.txt', 'topic': 'programming'},
#   {'source': 'sports.txt', 'topic': 'cricket'},
#   {'source': 'ml.txt', 'topic': 'machine_learning'},
#   {'source': 'geography.txt', 'topic': 'nature'},
#   {'topic': 'renewable_energy', 'source': 'energy.txt'},
#   {'topic': 'programming', 'source': 'python.txt'},
#   {'source': 'sports.txt', 'topic': 'cricket'},
#   {'source': 'ml.txt', 'topic': 'machine_learning'},
#   {'topic': 'nature', 'source': 'geography.txt'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'topic': 'programming', 'source': 'python.txt'},
#   {'source': 'sports.txt', 'topic': 'cricket'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'topic': 'nature', 'source': 'geography.txt'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'topic': 'programming', 'source': 'python.txt'},
#   {'topic': 'cricket', 'source': 'sports.txt'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'source': 'geography.txt', 'topic': 'nature'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'author': 'Manas'},
#   {'author': 'Manas Sharma'},
#   {'author': 'Manas'}]}

# %%
#update document
new_docs = Document(
    page_content="I am Manas Sharma",
    metadata= {'author':"Manas Sharma"}
)

vec_store.update_document(document_id='80158407-d90a-4a9a-a04e-a1b281eb8eb7', document=new_docs)

# %%
vec_store.delete(ids=['80158407-d90a-4a9a-a04e-a1b281eb8eb7'])
vec_store.get(include=["documents","embeddings","metadatas"])
# Out:
# {'ids': ['08d4b84d-f3a7-4e30-852e-630ad9ce03b7',
#   '29b624cd-b456-4e59-a4c5-d2cd46b11ca1',
#   '318499ce-9941-45f8-b25d-87a44286a2b2',
#   'd28956c2-9db1-4267-81da-975d82c6f258',
#   '54680e0d-b3b5-4bfc-8bbb-cab3240927f2',
#   '38317035-1db4-4e33-8cd1-e56d67fcac73',
#   'c0b718a1-a7c8-4886-ba7d-513d6598f8ea',
#   'e1aa3aac-7601-4955-a61a-21c62276197d',
#   '97ceeb82-c325-4935-b7d1-6e5f016ad772',
#   '6ff45217-faa3-4ed9-afe9-4484770b8a2d',
#   'e5bb583a-0472-4d13-b7f5-9fe694088fb6',
#   'd0a3be0d-166d-4830-8668-51d63d7ac195',
#   'e23583ef-6dd3-4ff9-b69f-96bb02afaad7',
#   '98ef2447-e0da-4378-99fd-f212d9f41981',
#   '6226bf99-bec2-4681-bdb2-cc47a0608694',
#   '5ab497d4-4e82-4ea2-a09a-68851e6828e9',
#   'd7aef786-b3c1-4823-9535-272deee9535d',
#   '422ff6d7-5f94-449c-802a-9b3d02a3d74a',
#   '4bc430e6-2f4f-4003-b0cf-2a0bc2bff10f',
#   '37772e87-c230-40aa-bcbc-9b87b3030c47',
#   'f730822e-ba87-49cd-9f20-8f678b0222b0',
#   'df5562ca-be2e-415e-baf4-6db5eb228f03',
#   '062ef0db-1ab5-4fcf-87cc-c86c96cdc668',
#   '93772d66-9412-4a05-b761-8919b59f0d1b',
#   '5416ca5b-1c70-461b-a712-9896ea6a7770',
#   '0973a22d-a139-4d28-90be-03bfef728887',
#   '69f9bed7-3e80-42ce-b37f-da0eeea11d61',
#   'b5dedae2-6b2b-4680-9547-ced4629d3430',
#   '056261e5-2db1-4f99-9fdb-bcb941763e0e',
#   'dc50db02-19d4-4a34-8b80-ba9613b0c685',
#   '110e22c7-405f-4969-9484-210d792960ac',
#   'f1f2fa62-5462-46a2-8373-338f7cb3dd26'],
#  'embeddings': array([[ 0.00735757,  0.0739252 , -0.19310905, ..., -0.0460284 ,
#          -0.04709939,  0.00983565],
#         [-0.00682915,  0.04281028, -0.17339639, ..., -0.00081563,
#          -0.02074972, -0.01806264],
#         [ 0.02338139,  0.04502665, -0.19164981, ..., -0.01838585,
#          -0.0637055 ,  0.01552957],
#         ...,
#         [-0.00119635,  0.00826253, -0.16780199, ..., -0.03213845,
#          -0.02195565, -0.02404436],
#         [-0.01715239, -0.01714413, -0.12987012, ..., -0.03701324,
#          -0.03970392, -0.0426118 ],
#         [-0.00119635,  0.00826253, -0.16780199, ..., -0.03213845,
#          -0.02195565, -0.02404436]], shape=(32, 768)),
#  'documents': ['The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   'Python is a popular programming language used for web development, data science, and artificial intelligence.',
#   'The Indian Premier League (IPL) is one of the most watched T20 cricket tournaments in the world.',
#   'Machine learning enables computers to learn patterns from data and make predictions without being explicitly programmed.',
#   'The Amazon rainforest is the largest tropical rainforest on Earth and is home to an incredible diversity of plants and animals.',
#   'Solar energy is a renewable source of power that converts sunlight into electricity using photovoltaic cells.',
#   "The person's name is Manas Sharma",
#   'I am Manas Sharma',
#   "The person's name is Manas Sharma"],
#  'uris': None,
#  'included': ['documents', 'embeddings', 'metadatas'],
#  'data': None,
#  'metadatas': [{'source': 'sports.txt', 'topic': 'cricket'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'source': 'geography.txt', 'topic': 'nature'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'topic': 'programming', 'source': 'python.txt'},
#   {'source': 'sports.txt', 'topic': 'cricket'},
#   {'source': 'ml.txt', 'topic': 'machine_learning'},
#   {'topic': 'nature', 'source': 'geography.txt'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'source': 'python.txt', 'topic': 'programming'},
#   {'source': 'sports.txt', 'topic': 'cricket'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'topic': 'nature', 'source': 'geography.txt'},
#   {'source': 'energy.txt', 'topic': 'renewable_energy'},
#   {'topic': 'programming', 'source': 'python.txt'},
#   {'topic': 'cricket', 'source': 'sports.txt'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'topic': 'nature', 'source': 'geography.txt'},
#   {'topic': 'renewable_energy', 'source': 'energy.txt'},
#   {'source': 'python.txt', 'topic': 'programming'},
#   {'topic': 'cricket', 'source': 'sports.txt'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'topic': 'nature', 'source': 'geography.txt'},
#   {'topic': 'renewable_energy', 'source': 'energy.txt'},
#   {'source': 'python.txt', 'topic': 'programming'},
#   {'topic': 'cricket', 'source': 'sports.txt'},
#   {'topic': 'machine_learning', 'source': 'ml.txt'},
#   {'topic': 'nature', 'source': 'geography.txt'},
#   {'topic': 'renewable_energy', 'source': 'energy.txt'},
#   {'author': 'Manas'},
#   {'author': 'Manas Sharma'},
#   {'author': 'Manas'}]}
